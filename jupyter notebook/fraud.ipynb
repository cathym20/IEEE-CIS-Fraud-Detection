# %% [markdown]
# Import statements

# %%
import pandas as pd 
import numpy as np

# %%
#train_transaction = pd.read_csv('../data/train_transaction.csv')
#train_identity = pd.read_csv('../data/train_identity.csv')

# %%
#df = train_transaction.merge(train_identity, on='TransactionID', how='left')

# %%
df.to_parquet('train_data_merged.parquet')

# %%
df = pd.read_parquet('train_data_merged.parquet')

# %%
df = df.sort_values('TransactionDT')

# %% [markdown]
# Exploratory Data Analysis

# %%
df.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        2987000        0          86400            68.5         W  13926
# 1        2987001        0          86401            29.0         W   2755
# 2        2987002        0          86469            59.0         W   4663
# 3        2987003        0          86499            50.0         W  18132
# 4        2987004        0          86506            50.0         H   4497
#
#    card2  card3       card4  card5  ...                id_31  id_32  \
# 0    NaN  150.0    discover  142.0  ...                  NaN    NaN
# 1  404.0  150.0  mastercard  102.0  ...                  NaN    NaN
# 2  490.0  150.0        visa  166.0  ...                  NaN    NaN
# 3  567.0  150.0  mastercard  117.0  ...                  NaN    NaN
# 4  514.0  150.0  mastercard  102.0  ...  samsung browser 6.2   32.0
#
#        id_33           id_34  id_35 id_36 id_37  id_38  DeviceType  \
# 0        NaN             NaN    NaN   NaN   NaN    NaN         NaN
# 1        NaN             NaN    NaN   NaN   NaN    NaN         NaN
# 2        NaN             NaN    NaN   NaN   NaN    NaN         NaN
# 3        NaN             NaN    NaN   NaN   NaN    NaN         NaN
# 4  2220x1080  match_status:2      T     F     T      T      mobile
#
#                       DeviceInfo
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4  SAMSUNG SM-G892A Build/NRD90M
#
# [5 rows x 434 columns]

# %%
df.isna().sum()
# Out:
# TransactionID          0
# isFraud                0
# TransactionDT          0
# TransactionAmt         0
# ProductCD              0
#                    ...
# id_36             449555
# id_37             449555
# id_38             449555
# DeviceType        449730
# DeviceInfo        471874
# Length: 434, dtype: int64

# %%
df.shape
# Out:
# (590540, 434)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        TransactionID        isFraud  TransactionDT  TransactionAmt  \
# count   5.905400e+05  590540.000000   5.905400e+05   590540.000000
# mean    3.282270e+06       0.034990   7.372311e+06      135.027176
# std     1.704744e+05       0.183755   4.617224e+06      239.162522
# min     2.987000e+06       0.000000   8.640000e+04        0.251000
# 25%     3.134635e+06       0.000000   3.027058e+06       43.321000
# 50%     3.282270e+06       0.000000   7.306528e+06       68.769000
# 75%     3.429904e+06       0.000000   1.124662e+07      125.000000
# max     3.577539e+06       1.000000   1.581113e+07    31937.391000
#
#                card1          card2          card3          card5  \
# count  590540.000000  581607.000000  588975.000000  586281.000000
# mean     9898.734658     362.555488     153.194925     199.278897
# std      4901.170153     157.793246      11.336444      41.244453
# min      1000.000000     100.000000     100.000000     100.000000
# 25%      6019.000000     214.000000     150.000000     166.000000
# 50%      9678.000000     361.000000     150.000000     226.000000
# 75%     14184.000000     512.000000     150.000000     226.000000
# max     18396.000000     600.000000     231.000000     237.000000
#
#                addr1          addr2  ...          id_17         id_18  \
# count  524834.000000  524834.000000  ...  139369.000000  45113.000000
# mean      290.733794      86.800630  ...     189.451377     14.237337
# std       101.741072       2.690623  ...      30.375360      1.561302
# min       100.000000      10.000000  ...     100.000000     10.000000
# 25%       204.000000      87.000000  ...     166.000000     13.000000
# 50%       299.000000      87.000000  ...     166.000000     15.000000
# 75%       330.000000      87.000000  ...     225.000000     15.000000
# max       540.000000     102.000000  ...     229.000000     29.000000
#
#                id_19          id_20        id_21        id_22        id_24  \
# count  139318.000000  139261.000000  5159.000000  5169.000000  4747.000000
# mean      353.128174     403.882666   368.269820    16.002708    12.800927
# std       141.095343     152.160327   198.847038     6.897665     2.372447
# min       100.000000     100.000000   100.000000    10.000000    11.000000
# 25%       266.000000     256.000000   252.000000    14.000000    11.000000
# 50%       341.000000     472.000000   252.000000    14.000000    11.000000
# 75%       427.000000     533.000000   486.500000    14.000000    15.000000
# max       671.000000     661.000000   854.000000    44.000000    26.000000
#
#              id_25        id_26         id_32
# count  5132.000000  5163.000000  77586.000000
# mean    329.608924   149.070308     26.508597
# std      97.461089    32.101995      3.737502
# min     100.000000   100.000000      0.000000
# 25%     321.000000   119.000000     24.000000
# 50%     321.000000   149.000000     24.000000
# 75%     371.000000   169.000000     32.000000
# max     548.000000   216.000000     32.000000
#
# [8 rows x 403 columns]

# %%
x = df.drop('isFraud',axis=1)
y = df['isFraud']

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

# %%
df_train, df_test = train_test_split(df, test_size=0.2, stratify=df.iloc[:,-1,],random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_train, df_test = train_test_split(df, test_size=0.2, stratify=df.iloc[:,-1,],random_state=42)
#
# File c:\Users\cathy\anaconda3\envs\text_analytics\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\cathy\anaconda3\envs\text_analytics\Lib\site-packages\sklearn\model_selection\_split.py:2945, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2941         CVClass = ShuffleSplit
#    2943     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
# -> 2945     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2947 xp, _, device = get_namespace_and_device(arrays[0])
#    2948 train, test = move_to(train, test, xp=xp, device=device)
#
# File c:\Users\cathy\anaconda3\envs\text_analytics\Lib\site-packages\sklearn\model_selection\_split.py:2434, in StratifiedShuffleSplit.split(self, X, y, groups)
#    2429 if groups is not None:
#    2430     warnings.warn(
#    2431         f"The groups parameter is ignored by {self.__class__.__name__}",
#    2432         UserWarning,
#    2433     )
# -> 2434 y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
#    2435 return super().split(X, y, groups)
#
# File c:\Users\cathy\anaconda3\envs\text_analytics\Lib\site-packages\sklearn\utils\validation.py:1074, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1068     raise ValueError(
#    1069         f"Found array with dim {array.ndim},"
#    1070         f" while dim <= 2 is required{context}."
#    1071     )
#    1073 if ensure_all_finite:
# -> 1074     _assert_all_finite(
#    1075         array,
#    1076         input_name=input_name,
#    1077         estimator_name=estimator_name,
#    1078         allow_nan=ensure_all_finite == "allow-nan",
#    1079     )
#    1081 if copy:
#    1082     if _is_numpy_namespace(xp):
#    1083         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\cathy\anaconda3\envs\text_analytics\Lib\site-packages\sklearn\utils\validation.py:118, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     116 if not is_array_api and X.dtype == np.dtype("object") and not allow_nan:
#     117     if _object_dtype_isnan(X).any():
# --> 118         raise ValueError("Input contains NaN")
#     120 # We need only consider float arrays, hence can early return for all else.
#     121 if not xp.isdtype(X.dtype, ("real floating", "complex floating")):
#
# ValueError: Input contains NaN

# %% [markdown]
# Feature Selection
